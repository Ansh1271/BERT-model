# %%
import torch    # type: ignore
import pandas as pd  # type: ignore
from transformers import BertTokenizer, BertForSequenceClassification       # type: ignore
from torch.utils.data import DataLoader, Dataset                                  # type: ignore
from tqdm import tqdm           # type: ignore

# %%
# Set the file path and chunk size for large dataset processing
file_path = "multiclass_dataset.csv"  # Replace with your actual file path
chunk_size = 10000  # Define an appropriate chunk size for memory management

# Set device for GPU usage and enable mixed precision if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float16 if torch.cuda.is_available() else torch.float32  # Use float16 if GPU is available

# %%
# Load BERT tokenizer and sentiment model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')
model = torch.nn.DataParallel(model)  # Enable multi-GPU if available
model.to(device).to(dtype)
model.eval()
# Out:
# DataParallel(
#   (module): BertForSequenceClassification(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(105879, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x BertLayer(
#             (attention): BertAttention(
#               (self): BertSdpaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (activation): Tanh()
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#     (classifier): Linear(in_features=768, out_features=5, bias=True)
#   )
# )

# %%
# Function to tokenize texts in a batch
def batch_tokenize(texts):
    return tokenizer(texts, return_tensors='pt', padding=True, truncation=True, max_length=512).to(device).to(dtype)

# Function to predict sentiment for a batch of texts
def batch_predict_sentiment(batch_texts):
    inputs = batch_tokenize(batch_texts)
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    probabilities = torch.softmax(logits, dim=-1)
    predicted_classes = torch.argmax(probabilities, dim=1).tolist()

    return predicted_classes  # Return predicted classes directly

# %%
# Process the dataset in chunks and save results incrementally
output_file = "updating_" + file_path  # Output file name
for chunk_id, df_chunk in enumerate(pd.read_csv(file_path, chunksize=chunk_size)):
    # Define a dataset and dataloader for the current chunk
    class TextDataset(Dataset):
        def __init__(self, texts):
            self.texts = texts

        def __len__(self):
            return len(self.texts)

        def __getitem__(self, idx):
            return self.texts[idx]

    dataset = TextDataset(df_chunk['Text'].tolist())
    batch_size = 8  # Smaller batch size for large datasets and FP16 mode
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    # Lists to collect labels and sentiment for this chunk
    all_labels = []
    all_sentiments = []

    # Process each batch within the current chunk
    for batch_texts in tqdm(dataloader, desc=f"Processing chunk {chunk_id + 1}", unit="batch"):
        predicted_classes = batch_predict_sentiment(batch_texts)

        # Adjust labels based on the predictions
        for index, pred_class in enumerate(predicted_classes):
            original_label = df_chunk['Label'].iloc[index]  # Get the original label
            if original_label == 1:  # If the original label is Neutral (1)
                if pred_class == 0:  # If the model predicts it as Negative (0)
                    all_labels.append(0)  # Change to Negative (0)
                    all_sentiments.append("Negative")
                else:
                    all_labels.append(1)  # Keep as Neutral (1)
                    all_sentiments.append("Neutral")
            else:
                all_labels.append(original_label)  # Keep other labels (0 or 2)
                if original_label == 0:
                    all_sentiments.append("Negative")
                elif original_label == 2:
                    all_sentiments.append("Positive")
    # Append processed sentiment results to the current DataFrame chunk
    df_chunk['Sentiment'] = all_sentiments
    df_chunk['Label'] = all_labels

    # Save each chunk to the output CSV incrementally
    if chunk_id == 0:
        df_chunk.to_csv(output_file, index=False, mode='w')  # Write header for the first chunk
    else:
        df_chunk.to_csv(output_file, index=False, mode='a', header=False)  # Append without header

print("Processing complete. All chunks saved to", output_file)
# Out:
# Processing chunk 1:   0%|          | 0/1250 [00:00<?, ?batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   0%|          | 1/1250 [00:00<05:23,  3.86batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   0%|          | 2/1250 [00:00<06:00,  3.46batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   0%|          | 3/1250 [00:00<05:46,  3.60batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   0%|          | 4/1250 [00:01<07:21,  2.82batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   0%|          | 5/1250 [00:01<07:33,  2.74batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   0%|          | 6/1250 [00:01<06:39,  3.12batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|          | 7/1250 [00:02<05:48,  3.57batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|          | 8/1250 [00:02<05:31,  3.75batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|          | 9/1250 [00:02<05:44,  3.61batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|          | 10/1250 [00:02<05:29,  3.77batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|          | 11/1250 [00:03<07:37,  2.71batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|          | 12/1250 [00:04<10:00,  2.06batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|          | 13/1250 [00:04<08:50,  2.33batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|          | 14/1250 [00:04<08:42,  2.37batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|          | 15/1250 [00:05<09:56,  2.07batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|▏         | 16/1250 [00:06<11:13,  1.83batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|▏         | 17/1250 [00:06<09:26,  2.18batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   1%|▏         | 18/1250 [00:06<09:06,  2.25batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 19/1250 [00:07<09:38,  2.13batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 20/1250 [00:08<10:23,  1.97batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 21/1250 [00:08<08:37,  2.38batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 22/1250 [00:09<13:07,  1.56batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 23/1250 [00:10<12:51,  1.59batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 24/1250 [00:10<11:35,  1.76batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 25/1250 [00:10<11:15,  1.81batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 26/1250 [00:11<09:26,  2.16batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 27/1250 [00:11<07:51,  2.60batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 28/1250 [00:11<08:29,  2.40batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 29/1250 [00:12<10:57,  1.86batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 30/1250 [00:13<12:51,  1.58batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   2%|▏         | 31/1250 [00:13<10:30,  1.93batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 32/1250 [00:14<08:37,  2.35batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 33/1250 [00:14<09:06,  2.23batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 34/1250 [00:14<07:34,  2.68batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 35/1250 [00:15<07:30,  2.69batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 36/1250 [00:15<06:52,  2.94batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 37/1250 [00:16<08:36,  2.35batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 38/1250 [00:16<07:21,  2.74batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 39/1250 [00:16<06:09,  3.28batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 40/1250 [00:16<05:31,  3.65batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 41/1250 [00:16<05:29,  3.67batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 42/1250 [00:17<05:04,  3.97batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   3%|▎         | 43/1250 [00:17<07:53,  2.55batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▎         | 44/1250 [00:18<08:51,  2.27batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▎         | 45/1250 [00:19<10:22,  1.94batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▎         | 46/1250 [00:19<08:53,  2.26batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▍         | 47/1250 [00:19<10:14,  1.96batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▍         | 48/1250 [00:21<13:36,  1.47batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▍         | 49/1250 [00:21<11:37,  1.72batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▍         | 50/1250 [00:21<10:05,  1.98batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▍         | 51/1250 [00:22<11:26,  1.75batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▍         | 52/1250 [00:22<10:39,  1.87batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▍         | 53/1250 [00:25<21:37,  1.08s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▍         | 54/1250 [00:26<23:41,  1.19s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▍         | 55/1250 [00:28<24:45,  1.24s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   4%|▍         | 56/1250 [00:28<21:36,  1.09s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▍         | 57/1250 [00:29<19:57,  1.00s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▍         | 58/1250 [00:30<18:14,  1.09batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▍         | 59/1250 [00:31<17:57,  1.10batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▍         | 60/1250 [00:32<18:09,  1.09batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▍         | 61/1250 [00:33<18:12,  1.09batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▍         | 62/1250 [00:34<18:18,  1.08batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▌         | 63/1250 [00:34<17:59,  1.10batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▌         | 64/1250 [00:36<24:45,  1.25s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▌         | 65/1250 [00:39<29:37,  1.50s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▌         | 66/1250 [00:40<31:26,  1.59s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▌         | 67/1250 [00:42<33:58,  1.72s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   5%|▌         | 68/1250 [00:44<35:31,  1.80s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▌         | 69/1250 [00:46<35:17,  1.79s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▌         | 70/1250 [00:47<29:34,  1.50s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▌         | 71/1250 [00:48<24:55,  1.27s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▌         | 72/1250 [00:49<26:41,  1.36s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▌         | 73/1250 [00:51<30:11,  1.54s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▌         | 74/1250 [00:52<25:56,  1.32s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▌         | 75/1250 [00:53<22:43,  1.16s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▌         | 76/1250 [00:54<20:27,  1.05s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▌         | 77/1250 [00:54<18:40,  1.05batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▌         | 78/1250 [00:56<20:43,  1.06s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▋         | 79/1250 [00:56<19:02,  1.03batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▋         | 80/1250 [00:59<25:40,  1.32s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   6%|▋         | 81/1250 [01:00<26:16,  1.35s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 82/1250 [01:01<27:03,  1.39s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 83/1250 [01:02<23:25,  1.20s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 84/1250 [01:03<23:21,  1.20s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 85/1250 [01:05<25:24,  1.31s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 86/1250 [01:07<30:15,  1.56s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 87/1250 [01:10<35:33,  1.83s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 88/1250 [01:12<37:21,  1.93s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 89/1250 [01:14<37:46,  1.95s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 90/1250 [01:15<32:34,  1.69s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 91/1250 [01:16<32:06,  1.66s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 92/1250 [01:17<27:24,  1.42s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   7%|▋         | 93/1250 [01:18<24:01,  1.25s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 94/1250 [01:20<26:40,  1.38s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 95/1250 [01:21<22:51,  1.19s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 96/1250 [01:21<20:04,  1.04s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 97/1250 [01:23<24:32,  1.28s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 98/1250 [01:24<23:49,  1.24s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 99/1250 [01:25<20:30,  1.07s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 100/1250 [01:27<25:00,  1.30s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 101/1250 [01:28<27:23,  1.43s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 102/1250 [01:29<23:39,  1.24s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 103/1250 [01:30<22:51,  1.20s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 104/1250 [01:32<24:25,  1.28s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 105/1250 [01:33<21:03,  1.10s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   8%|▊         | 106/1250 [01:33<18:33,  1.03batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▊         | 107/1250 [01:35<24:01,  1.26s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▊         | 108/1250 [01:37<27:34,  1.45s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▊         | 109/1250 [01:38<23:45,  1.25s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▉         | 110/1250 [01:39<25:04,  1.32s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▉         | 111/1250 [01:40<23:59,  1.26s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▉         | 112/1250 [01:41<21:28,  1.13s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▉         | 113/1250 [01:43<22:57,  1.21s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▉         | 114/1250 [01:43<19:40,  1.04s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▉         | 115/1250 [01:44<18:16,  1.04batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▉         | 116/1250 [01:45<17:31,  1.08batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▉         | 117/1250 [01:46<16:35,  1.14batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:   9%|▉         | 118/1250 [01:46<15:23,  1.23batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|▉         | 119/1250 [01:47<14:11,  1.33batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|▉         | 120/1250 [01:48<17:24,  1.08batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|▉         | 121/1250 [01:51<24:53,  1.32s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|▉         | 122/1250 [01:53<30:32,  1.62s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|▉         | 123/1250 [01:54<26:24,  1.41s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|▉         | 124/1250 [01:55<22:46,  1.21s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|█         | 125/1250 [01:55<19:50,  1.06s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|█         | 126/1250 [01:56<19:05,  1.02s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|█         | 127/1250 [01:57<16:51,  1.11batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|█         | 128/1250 [01:58<19:49,  1.06s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|█         | 129/1250 [01:59<18:07,  1.03batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|█         | 130/1250 [02:01<24:22,  1.31s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  10%|█         | 131/1250 [02:06<44:57,  2.41s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█         | 132/1250 [02:07<34:56,  1.88s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█         | 133/1250 [02:07<28:22,  1.52s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█         | 134/1250 [02:08<22:42,  1.22s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█         | 135/1250 [02:09<19:36,  1.06s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█         | 136/1250 [02:09<17:07,  1.08batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█         | 137/1250 [02:09<13:39,  1.36batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█         | 138/1250 [02:10<11:40,  1.59batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█         | 139/1250 [02:10<09:57,  1.86batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█         | 140/1250 [02:11<09:12,  2.01batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█▏        | 141/1250 [02:11<07:38,  2.42batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█▏        | 142/1250 [02:11<07:35,  2.43batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  11%|█▏        | 143/1250 [02:12<08:26,  2.19batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 144/1250 [02:13<11:28,  1.61batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 145/1250 [02:13<11:19,  1.63batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 146/1250 [02:14<11:23,  1.62batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 147/1250 [02:14<10:01,  1.83batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 148/1250 [02:15<08:40,  2.12batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 149/1250 [02:15<09:27,  1.94batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 150/1250 [02:16<08:41,  2.11batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 151/1250 [02:16<09:58,  1.84batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 152/1250 [02:17<13:06,  1.40batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 153/1250 [02:18<12:53,  1.42batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 154/1250 [02:19<13:06,  1.39batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 155/1250 [02:20<12:34,  1.45batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  12%|█▏        | 156/1250 [02:20<12:27,  1.46batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 157/1250 [02:21<12:01,  1.51batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 158/1250 [02:22<13:00,  1.40batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 159/1250 [02:22<13:39,  1.33batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 160/1250 [02:23<14:19,  1.27batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 161/1250 [02:24<11:44,  1.55batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 162/1250 [02:24<09:31,  1.90batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 163/1250 [02:24<08:23,  2.16batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 164/1250 [02:25<07:30,  2.41batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 165/1250 [02:25<07:16,  2.49batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 166/1250 [02:26<10:27,  1.73batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 167/1250 [02:27<11:58,  1.51batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  13%|█▎        | 168/1250 [02:28<13:36,  1.32batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▎        | 169/1250 [02:28<11:10,  1.61batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▎        | 170/1250 [02:29<10:41,  1.68batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▎        | 171/1250 [02:29<10:58,  1.64batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▍        | 172/1250 [02:30<10:58,  1.64batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▍        | 173/1250 [02:30<11:07,  1.61batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▍        | 174/1250 [02:31<09:32,  1.88batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▍        | 175/1250 [02:31<08:37,  2.08batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▍        | 176/1250 [02:32<07:56,  2.26batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▍        | 177/1250 [02:32<07:08,  2.50batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▍        | 178/1250 [02:32<06:40,  2.68batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▍        | 179/1250 [02:33<09:52,  1.81batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▍        | 180/1250 [02:34<09:54,  1.80batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  14%|█▍        | 181/1250 [02:35<12:06,  1.47batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▍        | 182/1250 [02:35<10:24,  1.71batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▍        | 183/1250 [02:35<09:22,  1.90batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▍        | 184/1250 [02:36<08:24,  2.11batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▍        | 185/1250 [02:36<07:59,  2.22batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▍        | 186/1250 [02:37<07:49,  2.27batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▍        | 187/1250 [02:37<07:50,  2.26batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▌        | 188/1250 [02:37<07:29,  2.36batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▌        | 189/1250 [02:38<07:21,  2.40batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▌        | 190/1250 [02:39<09:56,  1.78batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▌        | 191/1250 [02:40<12:10,  1.45batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▌        | 192/1250 [02:40<09:56,  1.77batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  15%|█▌        | 193/1250 [02:41<10:14,  1.72batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▌        | 194/1250 [02:41<09:55,  1.77batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▌        | 195/1250 [02:42<12:18,  1.43batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▌        | 196/1250 [02:43<13:27,  1.31batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▌        | 197/1250 [02:43<11:04,  1.58batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▌        | 198/1250 [02:44<09:33,  1.84batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▌        | 199/1250 [02:44<08:54,  1.97batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▌        | 200/1250 [02:44<08:15,  2.12batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▌        | 201/1250 [02:45<07:31,  2.32batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▌        | 202/1250 [02:46<09:40,  1.80batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▌        | 203/1250 [02:46<08:50,  1.97batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▋        | 204/1250 [02:47<10:20,  1.68batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▋        | 205/1250 [02:47<08:32,  2.04batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  16%|█▋        | 206/1250 [02:47<07:35,  2.29batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 207/1250 [02:48<09:36,  1.81batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 208/1250 [02:49<09:15,  1.88batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 209/1250 [02:49<08:18,  2.09batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 210/1250 [02:49<07:28,  2.32batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 211/1250 [02:50<07:05,  2.44batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 212/1250 [02:51<08:55,  1.94batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 213/1250 [02:52<13:07,  1.32batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 214/1250 [02:52<10:57,  1.58batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 215/1250 [02:52<09:06,  1.89batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 216/1250 [02:53<09:00,  1.91batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 217/1250 [02:54<09:25,  1.83batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  17%|█▋        | 218/1250 [02:54<10:04,  1.71batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 219/1250 [02:55<11:30,  1.49batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 220/1250 [02:56<12:44,  1.35batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 221/1250 [02:57<13:36,  1.26batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 222/1250 [02:58<14:32,  1.18batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 223/1250 [02:58<12:21,  1.39batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 224/1250 [02:59<12:41,  1.35batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 225/1250 [03:00<12:59,  1.31batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 226/1250 [03:00<10:42,  1.59batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 227/1250 [03:01<09:25,  1.81batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 228/1250 [03:01<08:37,  1.98batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 229/1250 [03:01<07:46,  2.19batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 230/1250 [03:02<07:04,  2.40batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  18%|█▊        | 231/1250 [03:02<06:56,  2.45batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▊        | 232/1250 [03:03<08:05,  2.10batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▊        | 233/1250 [03:04<09:57,  1.70batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▊        | 234/1250 [03:04<08:59,  1.88batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▉        | 235/1250 [03:04<07:55,  2.13batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▉        | 236/1250 [03:05<07:18,  2.31batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▉        | 237/1250 [03:05<07:32,  2.24batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▉        | 238/1250 [03:06<09:22,  1.80batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▉        | 239/1250 [03:06<07:55,  2.13batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▉        | 240/1250 [03:07<07:14,  2.33batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▉        | 241/1250 [03:08<09:56,  1.69batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▉        | 242/1250 [03:08<08:32,  1.97batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  19%|█▉        | 243/1250 [03:08<09:06,  1.84batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|█▉        | 244/1250 [03:09<08:17,  2.02batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|█▉        | 245/1250 [03:10<09:39,  1.73batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|█▉        | 246/1250 [03:10<08:19,  2.01batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|█▉        | 247/1250 [03:10<07:06,  2.35batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|█▉        | 248/1250 [03:11<06:47,  2.46batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|█▉        | 249/1250 [03:11<07:18,  2.28batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|██        | 250/1250 [03:11<07:02,  2.37batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|██        | 251/1250 [03:12<07:51,  2.12batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|██        | 252/1250 [03:12<07:35,  2.19batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|██        | 253/1250 [03:13<06:56,  2.40batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|██        | 254/1250 [03:13<07:21,  2.25batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|██        | 255/1250 [03:14<06:38,  2.50batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  20%|██        | 256/1250 [03:14<07:08,  2.32batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██        | 257/1250 [03:15<07:30,  2.21batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██        | 258/1250 [03:15<08:43,  1.90batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██        | 259/1250 [03:16<08:22,  1.97batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██        | 260/1250 [03:16<07:54,  2.09batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██        | 261/1250 [03:17<10:16,  1.60batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██        | 262/1250 [03:18<09:23,  1.75batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██        | 263/1250 [03:18<09:30,  1.73batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██        | 264/1250 [03:19<09:04,  1.81batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██        | 265/1250 [03:20<11:11,  1.47batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██▏       | 266/1250 [03:20<09:28,  1.73batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██▏       | 267/1250 [03:20<09:01,  1.82batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  21%|██▏       | 268/1250 [03:21<11:01,  1.48batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 269/1250 [03:24<18:05,  1.11s/batch]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 270/1250 [03:24<14:16,  1.14batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 271/1250 [03:24<12:33,  1.30batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 272/1250 [03:25<10:12,  1.60batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 273/1250 [03:25<08:35,  1.90batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 274/1250 [03:26<10:25,  1.56batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 275/1250 [03:27<12:21,  1.32batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 276/1250 [03:28<14:03,  1.15batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 277/1250 [03:29<14:36,  1.11batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 278/1250 [03:29<12:04,  1.34batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 279/1250 [03:30<10:13,  1.58batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 280/1250 [03:31<11:46,  1.37batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  22%|██▏       | 281/1250 [03:31<10:18,  1.57batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 282/1250 [03:32<09:17,  1.74batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 283/1250 [03:32<10:47,  1.49batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 284/1250 [03:33<10:03,  1.60batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 285/1250 [03:33<08:09,  1.97batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 286/1250 [03:34<08:42,  1.84batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 287/1250 [03:34<09:02,  1.77batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 288/1250 [03:35<07:43,  2.07batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 289/1250 [03:35<07:12,  2.22batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 290/1250 [03:36<08:44,  1.83batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 291/1250 [03:37<11:34,  1.38batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 292/1250 [03:38<10:44,  1.49batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  23%|██▎       | 293/1250 [03:38<08:44,  1.82batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▎       | 294/1250 [03:38<07:41,  2.07batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▎       | 295/1250 [03:39<07:03,  2.26batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▎       | 296/1250 [03:39<09:21,  1.70batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▍       | 297/1250 [03:40<08:07,  1.95batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▍       | 298/1250 [03:41<10:38,  1.49batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▍       | 299/1250 [03:42<11:23,  1.39batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▍       | 300/1250 [03:42<09:28,  1.67batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▍       | 301/1250 [03:42<09:00,  1.76batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▍       | 302/1250 [03:43<11:08,  1.42batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▍       | 303/1250 [03:44<09:41,  1.63batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▍       | 304/1250 [03:44<08:49,  1.79batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▍       | 305/1250 [03:45<07:39,  2.06batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  24%|██▍       | 306/1250 [03:45<07:36,  2.07batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  25%|██▍       | 307/1250 [03:46<08:35,  1.83batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  25%|██▍       | 308/1250 [03:46<08:09,  1.93batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  25%|██▍       | 309/1250 [03:47<07:56,  1.98batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  25%|██▍       | 310/1250 [03:47<07:06,  2.20batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 1:  25%|██▍       | 311/1250 [03:47<06:49,  2.29batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# ...
# Processing chunk 4:  33%|███▎      | 51/154 [00:22<00:51,  2.01batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  34%|███▍      | 52/154 [00:23<00:46,  2.17batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  34%|███▍      | 53/154 [00:24<00:58,  1.73batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  35%|███▌      | 54/154 [00:25<01:13,  1.35batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  36%|███▌      | 55/154 [00:25<00:58,  1.69batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  36%|███▋      | 56/154 [00:25<00:47,  2.05batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  37%|███▋      | 57/154 [00:26<00:42,  2.26batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  38%|███▊      | 58/154 [00:26<00:36,  2.62batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  38%|███▊      | 59/154 [00:26<00:34,  2.75batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  39%|███▉      | 60/154 [00:26<00:31,  3.01batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  40%|███▉      | 61/154 [00:27<00:27,  3.33batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  40%|████      | 62/154 [00:27<00:27,  3.33batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  41%|████      | 63/154 [00:28<00:38,  2.35batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  42%|████▏     | 64/154 [00:28<00:32,  2.76batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  42%|████▏     | 65/154 [00:28<00:36,  2.46batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  43%|████▎     | 66/154 [00:29<00:47,  1.87batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  44%|████▎     | 67/154 [00:30<00:44,  1.95batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  44%|████▍     | 68/154 [00:31<00:52,  1.64batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  45%|████▍     | 69/154 [00:31<00:41,  2.04batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  45%|████▌     | 70/154 [00:31<00:40,  2.10batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  46%|████▌     | 71/154 [00:32<00:43,  1.91batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  47%|████▋     | 72/154 [00:32<00:38,  2.12batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  47%|████▋     | 73/154 [00:33<00:33,  2.39batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  48%|████▊     | 74/154 [00:33<00:39,  2.04batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  49%|████▊     | 75/154 [00:34<00:38,  2.07batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  49%|████▉     | 76/154 [00:34<00:32,  2.41batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  50%|█████     | 77/154 [00:34<00:28,  2.70batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  51%|█████     | 78/154 [00:34<00:25,  3.00batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  51%|█████▏    | 79/154 [00:35<00:21,  3.42batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  52%|█████▏    | 80/154 [00:35<00:32,  2.27batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  53%|█████▎    | 81/154 [00:36<00:30,  2.40batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  53%|█████▎    | 82/154 [00:36<00:27,  2.64batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  54%|█████▍    | 83/154 [00:37<00:48,  1.46batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  55%|█████▍    | 84/154 [00:38<00:50,  1.39batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  55%|█████▌    | 85/154 [00:39<00:50,  1.37batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  56%|█████▌    | 86/154 [00:39<00:40,  1.69batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  56%|█████▋    | 87/154 [00:40<00:39,  1.70batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  57%|█████▋    | 88/154 [00:40<00:33,  1.95batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  58%|█████▊    | 89/154 [00:41<00:33,  1.93batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  58%|█████▊    | 90/154 [00:41<00:36,  1.75batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  59%|█████▉    | 91/154 [00:42<00:32,  1.93batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  60%|█████▉    | 92/154 [00:43<00:36,  1.69batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  60%|██████    | 93/154 [00:43<00:29,  2.05batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  61%|██████    | 94/154 [00:43<00:26,  2.29batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  62%|██████▏   | 95/154 [00:43<00:23,  2.52batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  62%|██████▏   | 96/154 [00:44<00:22,  2.58batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  63%|██████▎   | 97/154 [00:44<00:26,  2.12batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  64%|██████▎   | 98/154 [00:45<00:27,  2.04batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  64%|██████▍   | 99/154 [00:45<00:23,  2.34batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  65%|██████▍   | 100/154 [00:46<00:25,  2.15batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  66%|██████▌   | 101/154 [00:46<00:24,  2.20batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  66%|██████▌   | 102/154 [00:47<00:21,  2.46batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  67%|██████▋   | 103/154 [00:47<00:17,  2.86batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  68%|██████▊   | 104/154 [00:47<00:14,  3.34batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  68%|██████▊   | 105/154 [00:47<00:14,  3.48batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  69%|██████▉   | 106/154 [00:48<00:14,  3.41batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  69%|██████▉   | 107/154 [00:48<00:13,  3.58batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  70%|███████   | 108/154 [00:49<00:21,  2.19batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  71%|███████   | 109/154 [00:49<00:17,  2.58batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  71%|███████▏  | 110/154 [00:49<00:14,  3.09batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  72%|███████▏  | 111/154 [00:49<00:13,  3.24batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  73%|███████▎  | 112/154 [00:50<00:12,  3.32batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  73%|███████▎  | 113/154 [00:50<00:11,  3.58batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  74%|███████▍  | 114/154 [00:51<00:18,  2.15batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  75%|███████▍  | 115/154 [00:51<00:21,  1.85batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  75%|███████▌  | 116/154 [00:52<00:21,  1.75batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  76%|███████▌  | 117/154 [00:52<00:17,  2.17batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  77%|███████▋  | 118/154 [00:53<00:15,  2.28batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  77%|███████▋  | 119/154 [00:53<00:15,  2.19batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  78%|███████▊  | 120/154 [00:53<00:13,  2.51batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  79%|███████▊  | 121/154 [00:54<00:11,  2.87batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  79%|███████▉  | 122/154 [00:54<00:12,  2.62batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  80%|███████▉  | 123/154 [00:54<00:11,  2.76batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  81%|████████  | 124/154 [00:55<00:09,  3.05batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  81%|████████  | 125/154 [00:55<00:08,  3.56batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  82%|████████▏ | 126/154 [00:55<00:08,  3.29batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  82%|████████▏ | 127/154 [00:56<00:10,  2.62batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  83%|████████▎ | 128/154 [00:56<00:08,  3.02batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  84%|████████▍ | 129/154 [00:56<00:07,  3.32batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  84%|████████▍ | 130/154 [00:57<00:08,  2.80batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  85%|████████▌ | 131/154 [00:57<00:09,  2.35batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  86%|████████▌ | 132/154 [00:58<00:13,  1.66batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  86%|████████▋ | 133/154 [00:59<00:10,  2.00batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  87%|████████▋ | 134/154 [00:59<00:11,  1.70batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  88%|████████▊ | 135/154 [01:00<00:12,  1.52batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  88%|████████▊ | 136/154 [01:00<00:09,  1.91batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  89%|████████▉ | 137/154 [01:01<00:07,  2.22batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  90%|████████▉ | 138/154 [01:01<00:08,  1.96batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  90%|█████████ | 139/154 [01:02<00:06,  2.22batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  91%|█████████ | 140/154 [01:02<00:06,  2.23batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  92%|█████████▏| 141/154 [01:02<00:04,  2.69batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  92%|█████████▏| 142/154 [01:03<00:04,  2.55batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  93%|█████████▎| 143/154 [01:03<00:04,  2.54batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  94%|█████████▎| 144/154 [01:04<00:04,  2.10batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  94%|█████████▍| 145/154 [01:04<00:03,  2.57batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  95%|█████████▍| 146/154 [01:05<00:04,  1.96batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  95%|█████████▌| 147/154 [01:05<00:03,  1.79batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  96%|█████████▌| 148/154 [01:06<00:02,  2.12batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  97%|█████████▋| 149/154 [01:06<00:01,  2.53batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  97%|█████████▋| 150/154 [01:06<00:01,  2.69batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  98%|█████████▊| 151/154 [01:07<00:01,  2.38batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  99%|█████████▊| 152/154 [01:07<00:00,  2.67batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4:  99%|█████████▉| 153/154 [01:07<00:00,  2.92batch/s]Attempting to cast a BatchEncoding to type torch.float32. This is not supported.
# Processing chunk 4: 100%|██████████| 154/154 [01:08<00:00,  2.25batch/s]
# Processing complete. All chunks saved to updating_multiclass_dataset.csv
